# %%
import pandas
import matplotlib.pyplot as plt

single_word = pandas.read_csv("../data/benchmark/results/SingleWord.txt")
two_words = pandas.read_csv("../data/benchmark/results/TwoWords.txt")
three_words = pandas.read_csv("../data/benchmark/results/ThreeWords.txt")
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Summary for Single-Word Queries

# %%
single_word.describe()
# Out:
#             Spark       Mongo
# count  100.000000  100.000000
# mean   267.650000   50.140000
# std     55.475789   67.437816
# min    202.000000   18.000000
# 25%    232.250000   21.000000
# 50%    269.000000   24.000000
# 75%    286.250000   34.000000
# max    661.000000  279.000000

# %%
single_word.plot(title="100 Single-Word Queries", logy=True, ylabel="Query runtime in ms")
# Out:
# <Axes: title={'center': '100 Single-Word Queries'}, ylabel='Query runtime in ms'>

# %% [markdown]
# ### Summary for Two-Word Queries

# %%
two_words.describe()
# Out:
#              Spark        Mongo
# count   100.000000   100.000000
# mean    579.170000   390.630000
# std    1085.548096  1200.690346
# min     229.000000    24.000000
# 25%     267.000000    30.000000
# 50%     292.500000    54.000000
# 75%     368.000000   243.000000
# max    8700.000000  9711.000000

# %%
two_words.plot(title="100 Two-Word Queries", logy=True, ylabel="Query runtime in ms")
# Out:
# <Axes: title={'center': '100 Two-Word Queries'}, ylabel='Query runtime in ms'>

# %% [markdown]
# ### Summary for Three-Word Queries

# %%
three_words.describe()
# Out:
#               Spark         Mongo
# count    100.000000    100.000000
# mean     744.950000    572.820000
# std     2720.763631   2646.895015
# min      205.000000     25.000000
# 25%      261.750000     53.250000
# 50%      292.500000    128.000000
# 75%      443.750000    290.750000
# max    27021.000000  26008.000000

# %%
three_words.plot(title="100 Three-Word Queries", logy=True, ylabel="Query runtime in ms")
# Out:
# <Axes: title={'center': '100 Three-Word Queries'}, ylabel='Query runtime in ms'>
